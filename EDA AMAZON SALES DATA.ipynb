# %%
import pandas as pd

# %%
df=pd.read_excel('SALESDATA.xls')

# %%
df.head()
# Out:
#     CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000460 2017-01-01           158.04   2017-01-01          119156
# 1  10000460 2017-01-01           420.90   2017-01-01          119156
# 2  10000460 2017-01-01           663.41   2017-01-01          119156
# 3  10000460 2017-01-01           179.45   2017-01-01          119156
# 4  10000460 2017-01-01          1516.52   2017-01-01          119156
#
#   Item Class Item Number                          Item  Line Number  \
# 0        P01       29071     Nationeel Salted Pretzels         8000
# 1        P01       28401          Ebony Prepared Salad         4000
# 2        P01       29255          Thresher Spicy Mints         9000
# 3        P01       36001  Big Time Frozen Cheese Pizza        12000
# 4        P01       47550     Red Spade Turkey Hot Dogs        13000
#
#    List Price  ...  Sales Amount Sales Amount Based on List Price  \
# 0      181.44  ...        204.84                           362.88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65282 entries, 0 to 65281
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           65282 non-null  int64
#  1   DateKey                           65282 non-null  datetime64[ns]
#  2   Discount Amount                   65280 non-null  float64
#  3   Invoice Date                      65282 non-null  datetime64[ns]
#  4   Invoice Number                    65282 non-null  int64
#  5   Item Class                        56993 non-null  object
#  6   Item Number                       65241 non-null  object
#  7   Item                              65282 non-null  object
#  8   Line Number                       65282 non-null  int64
#  9   List Price                        65282 non-null  float64
#  10  Order Number                      65282 non-null  int64
# ...

# %%
gkk = df.groupby(['CustKey', 'DateKey'])
  
# Print the first value in each group
gkk.first()
# Out:
#                      Discount Amount Invoice Date  Invoice Number Item Class  \
# CustKey  DateKey
# 10000453 2017-01-06           238.21   2017-01-06          330097        P01
#          2019-01-13           546.76   2019-01-13          319240        P01
#          2019-01-21           238.21   2019-01-21          319710        P01
#          2019-01-25           201.23   2019-01-25          319903        P01
#          2019-01-28           453.42   2019-01-28          320294        P01
# ...                              ...          ...             ...        ...
# 10027583 2019-06-08           174.66   2019-06-08          303285        P01
#          2019-06-21           174.66   2019-06-21          304547        P01
#          2019-06-28           280.92   2019-06-28          305233        P01
#          2019-07-09           174.66   2019-07-09          306380        P01
#          2019-08-10           174.66   2019-08-10          308756        P01
#
# ...

# %%
gkk

# %%
gkk.head()
# Out:
#         CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0      10000460 2017-01-01         158.0400   2017-01-01          119156
# 1      10000460 2017-01-01         420.9000   2017-01-01          119156
# 2      10000460 2017-01-01         663.4100   2017-01-01          119156
# 3      10000460 2017-01-01         179.4500   2017-01-01          119156
# 4      10000460 2017-01-01        1516.5200   2017-01-01          119156
# ...         ...        ...              ...          ...             ...
# 65277  10026081 2019-12-31         272.5230   2019-12-31          329571
# 65278  10026081 2019-12-31         548.2520   2019-12-31          329573
# 65279  10026081 2019-12-31          26.2588   2019-12-31          329575
# 65280  10026081 2019-12-31         447.6400   2019-12-31          329574
# 65281  10026606 2019-12-31          15.7200   2019-12-31          329580
#
#       Item Class Item Number                          Item  Line Number  \
# ...

# %%
gkk = df.groupby(['Item'])
  
# Print the first value in each group
gkk.head()
# Out:
#         CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0      10000460 2017-01-01           158.04   2017-01-01          119156
# 1      10000460 2017-01-01           420.90   2017-01-01          119156
# 2      10000460 2017-01-01           663.41   2017-01-01          119156
# 3      10000460 2017-01-01           179.45   2017-01-01          119156
# 4      10000460 2017-01-01          1516.52   2017-01-01          119156
# ...         ...        ...              ...          ...             ...
# 63872  10025305 2019-12-13           559.80   2019-12-13          327898
# 64269  10021006 2019-12-21           313.28   2019-12-21          328688
# 64359  10016609 2019-12-22           331.73   2019-12-22          328732
# 64474  10021139 2019-12-23           479.74   2019-12-23          328906
# 64638  10020684 2019-12-27           286.92   2019-12-27          329087
#
#       Item Class Item Number                          Item  Line Number  \
# ...

# %%
# Simplest pivot table must have a dataframe
# and an index/list of index.
table = pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['CustKey'])

# %%
table
# Out:
#           Discount Amount  Sales Amount  Sales Amount Based on List Price  \
# CustKey
# 10000453       500.301733    548.782067                       1049.083800
# 10000455       786.095789   1179.143684                       1965.239474
# 10000456      2458.408942   2186.924904                       4645.333846
# 10000457       690.469474   1564.389474                       2254.858947
# 10000458      9694.191000  10352.805000                      20046.996000
# ...                   ...           ...                               ...
# 10027381       520.055545    657.360833                       1177.416379
# 10027560       771.030000   1154.350952                       1925.380952
# 10027572      1498.120169   1773.443654                       3271.563823
# 10027575       486.548000    709.724000                       1196.272000
# 10027583      1177.140400   3053.688000                       4230.828400
#
#           Sales Cost Amount  Sales Margin Amount  Sales Quantity
# ...

# %%
table1 = pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['DateKey'])

# %%
table1
# Out:
#             Discount Amount  Sales Amount  Sales Amount Based on List Price  \
# DateKey
# 2017-01-01      3554.793389   7345.192639                      10899.986028
# 2017-01-02      1227.230270   1442.516667                       2669.746937
# 2017-01-03      1305.624515   1306.118322                       2611.742836
# 2017-01-04      2720.475788   2815.745053                       5536.220841
# 2017-01-05     10816.487037  10528.960921                      21345.447958
# ...                     ...           ...                               ...
# 2019-12-27      4868.709575   4412.483208                       9281.192783
# 2019-12-28      1879.192862   2136.453077                       4015.645939
# 2019-12-29      1422.643672   2045.526513                       3468.170186
# 2019-12-30      1340.793665   1562.488797                       2903.282462
# 2019-12-31      1925.285332   2128.942370                       4054.227702
#
# ...

# %%
table2=pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['Invoice Date'])

# %%
table2
# Out:
#               Discount Amount  Sales Amount  Sales Amount Based on List Price  \
# Invoice Date
# 2017-01-01        3554.793389   7345.192639                      10899.986028
# 2017-01-02        1227.230270   1442.516667                       2669.746937
# 2017-01-03        1305.624515   1306.118322                       2611.742836
# 2017-01-04        2720.475788   2815.745053                       5536.220841
# 2017-01-05       10816.487037  10528.960921                      21345.447958
# ...                       ...           ...                               ...
# 2019-12-27        4868.709575   4412.483208                       9281.192783
# 2019-12-28        1879.192862   2136.453077                       4015.645939
# 2019-12-29        1422.643672   2045.526513                       3468.170186
# 2019-12-30        1340.793665   1562.488797                       2903.282462
# 2019-12-31        1925.285332   2128.942370                       4054.227702
#
# ...

# %%
df.head()
# Out:
#     CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000460 2017-01-01           158.04   2017-01-01          119156
# 1  10000460 2017-01-01           420.90   2017-01-01          119156
# 2  10000460 2017-01-01           663.41   2017-01-01          119156
# 3  10000460 2017-01-01           179.45   2017-01-01          119156
# 4  10000460 2017-01-01          1516.52   2017-01-01          119156
#
#   Item Class Item Number                          Item  Line Number  \
# 0        P01       29071     Nationeel Salted Pretzels         8000
# 1        P01       28401          Ebony Prepared Salad         4000
# 2        P01       29255          Thresher Spicy Mints         9000
# 3        P01       36001  Big Time Frozen Cheese Pizza        12000
# 4        P01       47550     Red Spade Turkey Hot Dogs        13000
#
#    List Price  ...  Sales Amount Sales Amount Based on List Price  \
# 0      181.44  ...        204.84                           362.88
# ...

# %%
table3=pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['Invoice Number'])
table4=pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['Item Class'])
table5=pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['Item Number'])
table6=pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['Item'])
table7=pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['Line Number'])
table8=pd.pivot_table(df,values=['Discount Amount','Sales Amount','Sales Amount Based on List Price','Sales Cost Amount','Sales Margin Amount','Sales Quantity'],index =['Item'])

# %%
table8.head()
# Out:
#                            Discount Amount  Sales Amount  \
# Item
# American Beef Bologna           339.113333    303.353333
# American Chicken Hot Dogs       273.443696    310.578043
# American Cole Slaw             -792.345000    792.345000
# American Corned Beef           3963.857885   3701.161058
# American Pimento Loaf           345.326071    390.734429
#
#                            Sales Amount Based on List Price  \
# Item
# American Beef Bologna                            642.466667
# American Chicken Hot Dogs                        584.021739
# American Cole Slaw                                 0.000000
# American Corned Beef                            7665.018942
# American Pimento Loaf                            736.060500
#
#                            Sales Cost Amount  Sales Margin Amount  \
# Item
# American Beef Bologna             210.015556            93.337778
# American Chicken Hot Dogs         100.921304           209.656739
# ...

# %%
table3.describe()
# Out:
#        Discount Amount   Sales Amount  Sales Amount Based on List Price  \
# count     24680.000000   24681.000000                      24681.000000
# mean       2270.773774    4639.064184                       6909.549376
# std       12620.110780   23329.419195                      30046.494119
# min     -255820.800000     200.010000                          0.000000
# 25%         234.500000     354.880000                        603.780000
# 50%         450.611667     636.150000                       1117.410000
# 75%         928.496850    1423.550000                       2496.898000
# max      343532.660000  555376.000000                     632610.160000
#
#        Sales Cost Amount  Sales Margin Amount  Sales Quantity
# count       24681.000000         24681.000000    24681.000000
# mean         2783.039268          1856.024916      100.003986
# std         14823.849880          8857.860632      691.147905
# min             0.000000         -3932.930000       -1.000000
# ...

# %%
table4.describe()
# Out:
#        Discount Amount  Sales Amount  Sales Amount Based on List Price  \
# count         2.000000      2.000000                          2.000000
# mean        947.599889   1012.141809                       1959.741698
# std         819.001606    910.749021                       1729.750627
# min         368.478300    368.145000                        736.623300
# 25%         658.039095    690.143404                       1348.182499
# 50%         947.599889   1012.141809                       1959.741698
# 75%        1237.160684   1334.140213                       2571.300897
# max        1526.721478   1656.138617                       3182.860096
#
#        Sales Cost Amount  Sales Margin Amount  Sales Quantity
# count           2.000000             2.000000        2.000000
# mean          562.520138           449.621671        7.733828
# std           514.232995           396.516026        2.982333
# min           198.902500           169.242500        5.625000
# ...

# %%
table5.describe()
# Out:
#        Discount Amount   Sales Amount  Sales Amount Based on List Price  \
# count       983.000000     983.000000                        983.000000
# mean       2046.088430    3813.615447                       5859.703877
# std       11933.593727   20136.188809                      28281.274568
# min      -24820.000000     200.550000                          0.000000
# 25%         190.750000     310.907167                        484.985938
# 50%         323.108837     455.289381                        760.788636
# 75%         573.803974    1084.829464                       1543.670732
# max      206683.000000  448913.955556                     455324.444444
#
#        Sales Cost Amount  Sales Margin Amount  Sales Quantity
# count         983.000000           983.000000      983.000000
# mean         2236.902416          1576.713031       65.682277
# std         12796.024260          7651.499875      494.187403
# min             0.000000         -2351.165455        1.000000
# ...

# %%
table6.describe()
# Out:
#        Discount Amount   Sales Amount  Sales Amount Based on List Price  \
# count       657.000000     657.000000                        657.000000
# mean       1785.285180    3389.580218                       5174.465262
# std        8103.679506   13260.559118                      18948.011449
# min      -13557.656280     200.800000                          0.000000
# 25%         210.342422     354.584063                        568.421739
# 50%         374.725000     549.746250                        920.052910
# 75%         769.830227    1513.230622                       2186.539111
# max      149845.175000  215537.438947                     280861.375000
#
#        Sales Cost Amount  Sales Margin Amount  Sales Quantity
# count         657.000000           657.000000      657.000000
# mean         1969.402236          1420.177982       56.415688
# std          7467.682866          5993.259597      251.424802
# min             0.000000         -1725.117692        1.000000
# ...

# %%
table7.describe()
# Out:
#        Discount Amount  Sales Amount  Sales Amount Based on List Price  \
# count       397.000000    397.000000                        397.000000
# mean       1916.820520   2028.397703                       3945.214577
# std        5098.373212   4763.102294                       9830.789027
# min           8.010000    202.860000                        378.290000
# 25%         529.257391    575.667500                       1113.261698
# 50%         856.867349    952.859213                       1807.380000
# 75%        1481.348710   1674.155000                       3212.175000
# max       77383.265000  68773.735000                     146157.000000
#
#        Sales Cost Amount  Sales Margin Amount  Sales Quantity
# count         397.000000           397.000000      397.000000
# mean         1177.993629           850.404075       13.662525
# std          3000.430177          1926.906858       28.169429
# min            77.720000           -17.110000        1.000000
# ...

# %%
table2.describe()
# Out:
#        Discount Amount  Sales Amount  Sales Amount Based on List Price  \
# count       559.000000    559.000000                        559.000000
# mean       1935.369195   3164.799004                       5100.048011
# std        1759.980654   2416.781475                       3755.916298
# min       -3194.046887    722.557959                          0.000000
# 25%         971.277339   1482.543971                       2500.414444
# 50%        1471.653502   2114.704054                       3647.144386
# 75%        2310.993521   4396.811453                       6867.246047
# max       10816.487037  13131.783692                      21345.447958
#
#        Sales Cost Amount  Sales Margin Amount  Sales Quantity
# count         559.000000           559.000000      559.000000
# mean         1861.340092          1303.458912       53.414852
# std          1485.380230           972.292238       60.094077
# min             0.000000           283.502326        1.000000
# ...

# %%
table8.describe()
# Out:
#        Discount Amount   Sales Amount  Sales Amount Based on List Price  \
# count       657.000000     657.000000                        657.000000
# mean       1785.285180    3389.580218                       5174.465262
# std        8103.679506   13260.559118                      18948.011449
# min      -13557.656280     200.800000                          0.000000
# 25%         210.342422     354.584063                        568.421739
# 50%         374.725000     549.746250                        920.052910
# 75%         769.830227    1513.230622                       2186.539111
# max      149845.175000  215537.438947                     280861.375000
#
#        Sales Cost Amount  Sales Margin Amount  Sales Quantity
# count         657.000000           657.000000      657.000000
# mean         1969.402236          1420.177982       56.415688
# std          7467.682866          5993.259597      251.424802
# min             0.000000         -1725.117692        1.000000
# ...

# %%
pip install dtale
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import dtale
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\SHAURY~1\AppData\Local\Temp/ipykernel_23108/815099219.py in <module>
# ----> 1 import dtale
#       2 import pandas as pd
#
# ~\anaconda3\lib\site-packages\dtale\__init__.py in <module>
#       1 import warnings
#       2
# ----> 3 from flask import Blueprint
#       4
#       5 with warnings.catch_warnings():
#
# ~\anaconda3\lib\site-packages\flask\__init__.py in <module>
#      12 # utilities we import from Werkzeug and Jinja2 that are unused
#      13 # in the module but are exported as public interface.
# ---> 14 from jinja2 import escape
#      15 from jinja2 import Markup
#      16 from werkzeug.exceptions import abort
#
# ImportError: cannot import name 'escape' from 'jinja2' (C:\Users\shaurya khanna\anaconda3\lib\site-packages\jinja2\__init__.py)

# %%
import pandas_profiling
import numpy as np


#descriptive statistics
pandas_profiling.ProfileReport(table8)

# %%
pip install sweetviz

# %%
import sweetviz
my_report  = sweetviz.analyze([table8,'Item'], target_feat='Sales Amount')
my_report.show_html('FinalReport.html')

# %%
from autoviz.AutoViz_Class import AutoViz_Class 
# %matplotlib inline

# %%
conda install -c plotly plotly=5.9.0

# %%
pip install "notebook>=5.3" "ipywidgets>=7.5"

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.pairplot(table2)

# %%
table2
# Out:
#               Discount Amount  Sales Amount  Sales Amount Based on List Price  \
# Invoice Date
# 2017-01-01        3554.793389   7345.192639                      10899.986028
# 2017-01-02        1227.230270   1442.516667                       2669.746937
# 2017-01-03        1305.624515   1306.118322                       2611.742836
# 2017-01-04        2720.475788   2815.745053                       5536.220841
# 2017-01-05       10816.487037  10528.960921                      21345.447958
# ...                       ...           ...                               ...
# 2019-12-27        4868.709575   4412.483208                       9281.192783
# 2019-12-28        1879.192862   2136.453077                       4015.645939
# 2019-12-29        1422.643672   2045.526513                       3468.170186
# 2019-12-30        1340.793665   1562.488797                       2903.282462
# 2019-12-31        1925.285332   2128.942370                       4054.227702
#
# ...

# %%
sns.lineplot(data=table2, x="Invoice Date", y="Discount Amount")
# Out:
# <AxesSubplot:xlabel='Invoice Date', ylabel='Discount Amount'>

# %%
sns.lineplot(data=table2, x="Invoice Date", y="Sales Amount")
# Out:
# <AxesSubplot:xlabel='Invoice Date', ylabel='Sales Amount'>

# %%
g = sns.PairGrid(table2)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
# Scatter Plot
sns.scatterplot(x='Invoice Date', y='Sales Cost Amount', data=table2)
# Out:
# <AxesSubplot:xlabel='Invoice Date', ylabel='Sales Cost Amount'>

# %%
table2.columns
# Out:
# Index(['Discount Amount', 'Sales Amount', 'Sales Amount Based on List Price',
#        'Sales Cost Amount', 'Sales Margin Amount', 'Sales Quantity'],
#       dtype='object')

# %%
sns.distplot(table2['Sales Amount'])
# Out:
# C:\Users\shaurya khanna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales Amount', ylabel='Density'>

# %%
# bar plot
sns.barplot(x='Invoice Date',y='Sales Quantity', data=table2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHAURY~1\AppData\Local\Temp/ipykernel_23108/368302096.py in <module>
#       1 # bar plot
# ----> 2 sns.barplot(x='Invoice Date',y='Sales Quantity', data=table2)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %%
sns.heatmap(table2,annot=True,fmt='.2f' )
# Out:
# <AxesSubplot:ylabel='Invoice Date'>
